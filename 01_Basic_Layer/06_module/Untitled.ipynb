# %%
# 先查看当前路径（确认是否在06_Module里）
import os
print("当前路径：", os.getcwd())  # 输出要包含「06_Module」

# 如果路径不对，切换到06_Module文件夹（把下面的路径改成你自己的！）
os.chdir("/你的完整路径/UNNC-EEE-RaspberryPi-Car/01_Basic_Layer/06_Module")

# 运行主程序
# %run car_main.py
# Out:
# 当前路径： F:\ASUS\Desktop\UNNC-EEE-RaspberryPi-Car\01_Basic_Layer\06_module
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 print("当前路径：", os.getcwd())  # 输出要包含「06_Module」
#       5 # 如果路径不对，切换到06_Module文件夹（把下面的路径改成你自己的！）
# ----> 6 os.chdir("/你的完整路径/UNNC-EEE-RaspberryPi-Car/01_Basic_Layer/06_Module")
#       8 # 运行主程序
#       9 get_ipython().run_line_magic('run', 'car_main.py')
#
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: '/你的完整路径/UNNC-EEE-RaspberryPi-Car/01_Basic_Layer/06_Module'

# %%
# 先查看当前路径（确认是否在06_Module里）
import os
print("当前路径：", os.getcwd())  

# 直接切换到你当前的06_Module目录（不用改，直接复制用）
# 注意：Windows系统用反斜杠 \，Python里要写转义符 \\ 或者用正斜杠 /
target_path = r"F:\ASUS\Desktop\UNNC-EEE-RaspberryPi-Car\01_Basic_Layer\06_module"

# 如果路径不对，才执行切换（避免报错）
if os.getcwd() != target_path:
    os.chdir(target_path)

# 再次查看路径
print("切换后路径：", os.getcwd())

# 运行主程序
# %run car_main.py
# Out:
# 当前路径： F:\ASUS\Desktop\UNNC-EEE-RaspberryPi-Car\01_Basic_Layer\06_module
# 切换后路径： F:\ASUS\Desktop\UNNC-EEE-RaspberryPi-Car\01_Basic_Layer\06_module
# 🚗 小车开始智能行驶！
#
# === 执行第1段路径 ===
# ✅ 执行成功 | 方向：forward | 速度：28 | 距离：12 | 车灯：关
#
# === 执行第2段路径 ===
# ⚠️ 速度超标（55），修正为50
# ✅ 执行成功 | 方向：right | 速度：50 | 距离：6 | 车灯：关
#
# === 执行第3段路径 ===
# ⚠️ 速度过低（5），修正为8
# ✅ 执行成功 | 方向：forward | 速度：8 | 距离：18 | 车灯：关
#
# === 执行第4段路径 ===
# ❌ 距离非法（≤0）
#
# === 执行第5段路径 ===
# ❌ 方向非法（up）
#
# === 执行第6段路径 ===
# ✅ 速度≥30且正向行驶，打开车灯
# ✅ 执行成功 | 方向：forward | 速度：32 | 距离：15 | 车灯：开
#
# ================ 行驶完成 ================
# 📊 总有效距离：51 米
# 📊 正向行驶距离：45 米
# 📊 开灯路段数：1 段
# 📊 最高速度：50 km/h
# 📊 平均速度：29.5 km/h
